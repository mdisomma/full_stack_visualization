# %%
import pandas as pd

# %%
data_file = "Data/City_Service_Requests_in_2010.csv"
data_file_1 = "Data/City_Service_Requests_in_2011.csv"
data_file_2 = "Data/City_Service_Requests_in_2012.csv"
data_file_3 = "Data/City_Service_Requests_in_2013.csv"
data_file_4 = "Data/City_Service_Requests_in_2014.csv"
data_file_5 = "Data/City_Service_Requests_in_2015.csv"
data_file_6 = "Data/City_Service_Requests_in_2016.csv"
data_file_7 = "Data/City_Service_Requests_in_2017.csv"
data_file_8 = "Data/City_Service_Requests_in_2018.csv"

# %%
data_2010 = pd.read_csv(data_file)
data_2011 = pd.read_csv(data_file_1)
data_2012 = pd.read_csv(data_file_2)
data_2013 = pd.read_csv(data_file_3)
data_2014 = pd.read_csv(data_file_4)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_2015 = pd.read_csv(data_file_5)
data_2016 = pd.read_csv(data_file_6)
data_2017 = pd.read_csv(data_file_7)
data_2018 = pd.read_csv(data_file_8)
#data_2019 = pd.read_csv(data_file_9)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Out:
#         OBJECTID        SERVICECODEDESCRIPTION                   ADDDATE  \
# 0        1715224          Parking Meter Repair  2013-03-12T14:14:55.000Z
# 1        1715225          Parking Meter Repair  2013-03-18T18:38:58.000Z
# 2        1715226          Parking Meter Repair  2013-03-15T20:02:29.000Z
# 3        1715227              Sign Replacement  2013-03-15T16:17:44.000Z
# 4        1715228          Parking Meter Repair  2013-03-11T14:24:26.000Z
# 5        1715229          Parking Meter Repair  2013-03-26T14:50:41.000Z
# 6        1715230          Parking Meter Repair  2013-04-06T16:05:11.000Z
# 7        1715231          Parking Meter Repair  2013-04-06T17:08:42.000Z
# 8        1715232          Parking Meter Repair  2013-03-27T14:16:18.000Z
# 9        1715233          Parking Meter Repair  2013-03-26T14:34:27.000Z
# 10       1715234          Parking Meter Repair  2013-03-12T12:38:34.000Z
# 11       1715235          Parking Meter Repair  2013-04-04T14:12:32.000Z
# ...

# %%
grouped_2010_data = data_2010.groupby("SERVICECODEDESCRIPTION").count()
grouped_2010_data.sort_values("X", ascending=False).head(15)
# Out:
#                                                    X      Y  OBJECTID  \
# SERVICECODEDESCRIPTION
# Parking Meter Repair                           17650  17650     17650
# Snow/Ice Removal                                1570   1570      1570
# Rat Abatement                                   1448   1448      1448
# Bulk Collection                                 1065   1065      1065
# How's My Driving - Complaint                     809    809       809
# Streetlight Repair Investigation                 523    523       523
# Alley Cleaning                                   518    518       518
# Sidewalk Repair                                  442    442       442
# Out of State Parking Violation (ROSA)            394    394       394
# xxx_Curb & Gutter Repair - Major LOOK UP ONLY    387    387       387
# xxx_Tree Trimming LOOK UP ONLY                   384    384       384
# xxx_Street Repairs LOOK UP ONLY                  383    383       383
# ...

# %%
grouped_2011_data = data_2011.groupby("SERVICECODEDESCRIPTION").count()
grouped_2011_data.sort_values("X", ascending=False).head(15)
# Out:
#                                             X     Y  OBJECTID  SERVICECODE  \
# SERVICECODEDESCRIPTION
# Parking Meter Repair                     1973  1973      1973         1973
# Parking Enforcement                      1874  1874      1874         1874
# How's My Driving - Complaint              941   941       941          941
# Rat Abatement                             833   833       833          833
# Bulk Collection                           585   585       585          585
# Snow/Ice Removal                          527   527       527          527
# Sidewalk Repair                           413   413       413          413
# Wire Down / Power Outage                  407   407       407          407
# DCRA - Trash and Debris                   325   325       325          325
# CSR Reported Issues                       291   291       291          291
# Abandoned Vehicle - On Public Property    286   286       286          286
# ...

# %%
grouped_2012_data = data_2012.groupby("SERVICECODEDESCRIPTION").count()
grouped_2012_data.sort_values("X", ascending=False).head(15)
# Out:
#                                       X      Y  OBJECTID  SERVICECODE  \
# SERVICECODEDESCRIPTION
# Parking Meter Repair              62814  62814     62814        62814
# Bulk Collection                   35334  35334     35334        35334
# Parking Meter Issues              31523  31523     31523        31523
# Parking Meter Request             24016  24016     24016        24016
# Parking Enforcement               15874  15874     15874        15874
# Tree Inspection                    6842   6842      6842         6842
# Alley Cleaning                     5727   5727      5727         5727
# Trash Collection - Missed          5257   5257      5257         5257
# Sanitation Enforcement             4765   4765      4765         4765
# Streetlight Repair Investigation   4104   4104      4104         4104
# Recycling Collection - Missed      3472   3472      3472         3472
# TRU Report                         3442   3442      3442         3442
# ...

# %%
grouped_2013_data = data_2013.groupby("SERVICECODEDESCRIPTION").count()
grouped_2013_data.sort_values("SERVICECODEDESCRIPTION", ascending=False).head(25)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-bf28cce28393> in <module>
#       1 grouped_2013_data = data_2013.groupby("SERVICECODEDESCRIPTION").count()
# ----> 2 fil_2013_data = grouped_2013_data[["OBJECTID", "SERVICECODEDESCRIPTION", "ADDDATE", "RESOLUTIONDATE", "LATITUDE", "LONGITUDE", "WARD", "DETAILS"]]
#       3 grouped_2013_data.sort_values("SERVICECODEDESCRIPTION", ascending=False).head(25)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ...

# %%
grouped_2014_data = data_2014.groupby("SERVICECODEDESCRIPTION").count()
grouped_2014_data.sort_values("X", ascending=False).head(15)
# Out:
#                                           X      Y  OBJECTID  SERVICECODE  \
# SERVICECODEDESCRIPTION
# Parking Meter Repair                  92571  92571     92571        92571
# Bulk Collection                       43097  43097     43097        43097
# Parking Enforcement                   26714  26714     26714        26714
# CONTAINER REMOVAL                     24634  24634     24634        24634
# Pothole                               11348  11348     11348        11348
# Trash Collection - Missed              9008   9008      9008         9008
# Streetlight Repair Investigation       8594   8594      8594         8594
# Alley Cleaning                         7793   7793      7793         7793
# Recycling Collection - Missed          7117   7117      7117         7117
# Sanitation Enforcement                 6796   6796      6796         6796
# Emergency No-Parking Verification      6061   6061      6061         6061
# ...

# %%
grouped_2015_data = data_2015.groupby("SERVICECODEDESCRIPTION").count()
grouped_2015_data.sort_values("X", ascending=False).head(15)
# Out:
#                                           X      Y  OBJECTID  SERVICECODE  \
# SERVICECODEDESCRIPTION
# Parking Meter Repair                  65164  65164     65164        65164
# Bulk Collection                       43990  43990     43990        43990
# Parking Enforcement                   29035  29035     29035        29035
# Pothole                               16765  16765     16765        16765
# Streetlight Repair Investigation      10321  10321     10321        10321
# Emergency No-Parking Verification      9865   9865      9865         9865
# Alley Cleaning                         7889   7889      7889         7889
# Trash Collection - Missed              7843   7843      7843         7843
# Sanitation Enforcement                 6963   6963      6963         6963
# Residential Parking Permit Violation   5967   5967      5967         5967
# Street Cleaning                        5411   5411      5411         5411
# ...

# %%
grouped_2016_data = data_2016.groupby("SERVICECODEDESCRIPTION").count()
grouped_2016_data.sort_values("X", ascending=False).head(15)
# Out:
#                                               X      Y  OBJECTID  SERVICECODE  \
# SERVICECODEDESCRIPTION
# Bulk Collection                           45404  45404     45404        45404
# Parking Meter Repair                      34078  34078     34078        34078
# Parking Enforcement                       33733  33733     33733        33733
# Emergency No-Parking Verification         12644  12644     12644        12644
# Streetlight Repair Investigation          12344  12344     12344        12344
# Pothole                                   11225  11225     11225        11225
# Trash Collection - Missed                  8159   8159      8159         8159
# Alley Cleaning                             7285   7285      7285         7285
# Residential Parking Permit Violation       6680   6680      6680         6680
# Sanitation Enforcement                     6424   6424      6424         6424
# Sidewalk Shoveling Enforcement Exemption   5777   5777      5777         5777
# ...

# %%
grouped_2017_data = data_2017.groupby("SERVICECODEDESCRIPTION").count()
grouped_2017_data.sort_values("X", ascending=False).head(15)
# Out:
#                                           X      Y  OBJECTID  SERVICECODE  \
# SERVICECODEDESCRIPTION
# Bulk Collection                       50625  50625     50625        50625
# Parking Enforcement                   37249  37249     37249        37249
# Parking Meter Repair                  31767  31767     31767        31767
# Roadway Signs                         15586  15586     15586        15586
# Emergency No-Parking Verification     13971  13971     13971        13971
# Streetlight Repair Investigation      12437  12437     12437        12437
# Sanitation Enforcement                 9649   9649      9649         9649
# Trash Collection - Missed              9247   9247      9247         9247
# Residential Parking Permit Violation   8410   8410      8410         8410
# Alley Cleaning                         7856   7856      7856         7856
# Pothole                                6942   6942      6942         6942
# ...

# %%
grouped_2018_data = data_2018.groupby("SERVICECODEDESCRIPTION").count()
grouped_2018_data.sort_values("X", ascending=False).head(15)
# Out:
#                                             X      Y  OBJECTID  SERVICECODE  \
# SERVICECODEDESCRIPTION
# Bulk Collection                         54894  54894     54894        54894
# Parking Enforcement                     40929  40929     40929        40929
# Parking Meter Repair                    40771  40771     40771        40771
# Emergency No-Parking Verification       16793  16793     16793        16793
# Sanitation Enforcement                  11877  11877     11877        11877
# Streetlight Repair Investigation        11726  11726     11726        11726
# Trash Collection - Missed               11555  11555     11555        11555
# Roadway Signs                           11518  11518     11518        11518
# Pothole                                 10869  10869     10869        10869
# Residential Parking Permit Violation     9589   9589      9589         9589
# Illegal Dumping                          7959   7959      7959         7959
# ...
